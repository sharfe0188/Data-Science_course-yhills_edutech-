# %% [markdown]
# **What is Machine Learning?**
# Machine learning is a branch of AI(Artificial Intelligence) that enables computer to learn from data and improve their performance over time without being explicitly programmed.
#
# Types of ML?
# 1. Supervised Learning
# 2. Unsupervised Learning
# 3. Reinforcement Learning

# %% [markdown]
# **Supervised Learning**
# house size = 100sqft, location = onroad, rooms =3(input) , prize = 20lakhs (output)
#
# house size = 200sqft, location = onroad, rooms =6(input) , prize = 40lakhs (output)
#
# house size = 300sqft, location = onroad, rooms =9(input) , prize = ?  (output)

# %% [markdown]
# **Regression**
#
# Regression involves predicting continuous values . example : predicting house price based on the size, salary based on experience .
#
# **Classification**
#
# It involves predicting a category or class label for new observation . example : classifying emails, True or false

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score #It is used to evaluate the accuracy of our model
import matplotlib.pyplot as plt

#Loading sample data
x = np.array([650,700,800,900,1100,1500,1800,2200,2400,3000]).reshape(-1,1) #Feature(size) in sqrft
y = np.array([150,160,170,180,200,250,300,400,420,500]) #Target(Price)

#Split the data into training and testing data
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=42)

#Create a linear regression model
model = LinearRegression()
model.fit(x_train, y_train)

#Make predictions on the test data
y_pred = model.predict(x_test)

#Evaluate the model
accuracy = model.score(x_test, y_pred)
print("accuracy",accuracy)
print(f"Accuracy:{accuracy*100:.2f}%")

#Visualize the result

plt.scatter(x_train,y_train,color='blue',label='Training Data')
plt.scatter(x_test,y_test,color='green',label='Testing Data')
plt.plot(x, model.predict(x),color = 'red',label = "Linear Regression Line")
plt.xlabel("Size(sqft)")
plt.ylabel("Price(lakhs)")
plt.title("House Price Prediction")
plt.legend()
plt.show()
# Out:
# accuracy 1.0
# Accuracy:100.00%

# %%
new_size =np.array([[4500]])
predicted_price = model.predict(new_size)
print(predicted_price)
print(f"The predicted_price for a {new_size} sqft house is {predicted_price[0]:.2f} thousand ")
# Out:
# [729.3143366]
# The predicted_price for a [[4500]] sqft house is 729.31 thousand

# %%
pip install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.distplot([0,1,2,3,4,5])
plt.show()
# Out:
# <ipython-input-11-167f001e5aaa>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0,1,2,3,4,5])

# %%
#Normal Distribution
from numpy import random
x = random.normal(size=(2,3))
print(x)
# Out:
# [[-1.26953297  0.6332607  -0.97441354]
#  [ 0.51221053 -1.61461106 -1.42371204]]

# %%
#loc - mean(peak of bell)
#scale - (standard deviation) how flat the graph distribution should be
#size - the shape of the returned array

x = random.normal(loc=1,scale=2,size=(2,3))
print(x)
# Out:
# [[ 2.07764525  6.69555156 -1.21412198]
#  [ 2.63011308 -0.83187477  1.03895896]]

# %%
sns.distplot(random.normal(size=1000),hist=False)
plt.show()
# Out:
# <ipython-input-14-ebed98147b7e>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=1000),hist=False)

# %%
#Poisson Distribution
from numpy import random
x = random.poisson(lam = 2,size = 10)
print(x)
# Out:
# [1 0 4 3 1 0 0 5 5 3]

# %%
sns.displot(random.poisson(lam=2,size = 1000),kde = True)
